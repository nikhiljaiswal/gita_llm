# %%
import sys
import sqlite3
import os
import streamlit as st
from dotenv import load_dotenv, find_dotenv
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA, LLMChain
from langchain.chat_models import ChatOpenAI
from langchain.prompts.chat import  ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate
from langchain.prompts import PromptTemplate
from langchain.chains import ConversationalRetrievalChain

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
class LLM_QA:
    """
    Defines the method to perform QA over given source of data using LLM Models
    """

    def load_document(self,file):
        """
        Loads PDF, DOCX and TXT files as LangChain Documents

        Args:
            file: the input file which needs to be loaded as Langchain document
        Returns:
            data: <langchain loader> a langchain loader object
        """
        _, extension = os.path.splitext(file)

        if extension == '.pdf':
            from langchain.document_loaders import PyPDFLoader
            print(f'Loading {file}')
            loader = PyPDFLoader(file)
        elif extension == '.docx':
            from langchain.document_loaders import Docx2txtLoader
            print(f'Loading {file}')
            loader = Docx2txtLoader(file)
        elif extension == '.txt':
            from langchain.document_loaders import TextLoader
            loader = TextLoader(file, encoding='utf8')
        else:
            print('Document format is not supported!')
            return None
        data = loader.load()
        return data

    def chunk_data(self,data, chunk_size=256, chunk_overlap=0):
        """
        Splits the data into chunks

        Args:
            data: <langchain loader> a langchain loader object
            chunk_size: <int> integer input which suggest what should be the chunk size
            chunk_overlap: <int> integer determining the chunk overlap size
        Returns:
            chunks: <langchain chunk object> a langchain chunk object
        """
        from langchain.text_splitter import RecursiveCharacterTextSplitter
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
        chunks = text_splitter.split_documents(data)
        return chunks

    def create_embeddings(self,chunks):
        """
        Create embeddings using OpenAIEmbeddings() and save them in a Chroma vector store

        Args:
            chunks: <langchain chunk object> a langchain chunk object
        Returns:
            vector_store: <vector store> a vectore store which stores the generated embeddings
        """
        embeddings = OpenAIEmbeddings()
        vector_store = Chroma.from_documents(chunks, embeddings)
        return vector_store

    def calculate_embedding_cost(self,texts):
        """
        Calculate embedding cost using tiktoken

        Args:
            texts: <str> the input text
        Returns:
            total_tokens: <str> total tokens present in the input text
            embedding cost: <float> the estimated embedding cost
        """
        import tiktoken
        enc = tiktoken.encoding_for_model('text-embedding-ada-002')
        total_tokens = sum([len(enc.encode(page.page_content)) for page in texts])
        return total_tokens, total_tokens / 1000 * 0.0004

    def identify_source_language(self,query):
        """
        Identifies the language of the query

        Args:
            query: <str> the input query
        Returns:
            source_language: <str> language of the query
        """
        system_template_lang_detection = "I want you act as a language detector. I will input a sentence in any language and you will answer me in which language the sentence I wrote is in. Do not write any explanations or other words, just reply with the language name"
        human_template_lang_detection = "Sentence: {source_sentence}"

        system_prompt_lang_detection = SystemMessagePromptTemplate.from_template(system_template_lang_detection)
        human_prompt_lang_detection = HumanMessagePromptTemplate.from_template(human_template_lang_detection)
        lang_detection_prompt = ChatPromptTemplate.from_messages([system_prompt_lang_detection, human_prompt_lang_detection])

        lang_detection_chain = LLMChain(llm=llm, prompt=lang_detection_prompt)
        source_language = lang_detection_chain.run(source_sentence=query)
        return source_language

    def translate_text(self,query,source_language,target_language):
        """
        Translate the given query from source_language to target_language

        Args:
            query: <str> the input query which needs to be translated
            source_language: <str> source language of the query
            target_language: <str> target language of the query
        Returns:
            target_sentence: <str> the translated sentence in target language
        """
        system_template_translation = "You are a good Translator. Translate this sentence from {source_language} to {target_language}. Do not write any other words, just reply with the translated sentence."
        human_template_translation = "Sentence: {source_sentence}"

        system_prompt_translation = SystemMessagePromptTemplate.from_template(system_template_translation)
        human_prompt_translation = HumanMessagePromptTemplate.from_template(human_template_translation)
        translation_prompt = ChatPromptTemplate.from_messages([system_prompt_translation, human_prompt_translation])
        translation_chain = LLMChain(llm=llm, prompt=translation_prompt)
        target_sentence = translation_chain.run(source_language=source_language,source_sentence=query,target_language=target_language)
        return target_sentence

    def ask_and_get_answer(self,vector_store, query, k=3):
        """
        Given a vector store and input query use LLM Chain to return the answer

        Args:
            vector_store: <vector store> a vectore store which stores the embeddings
            query: <str> the input query
            k: <int> integer determining number of documents to be retreived
        Returns:
            answer: <str> the generated answer
        """
        retriever = vector_store.as_retriever(search_type='similarity', search_kwargs={'k': k})
        chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=retriever)
        answer = chain.run(query)
        return answer

    def ask_and_get_answer_only_if_present(self,vector_store, query, k=3):
        """
        Given a vector store and input query use LLM Chain to return the answer with minimization of hallucinations

        Args:
            vector_store: <vector store> a vectore store which stores the embeddings
            query: <str> the input query
            k: <int> integer determining number of documents to be retreived
        Returns:
            answer: <str> the generated answer
        """
        prompt_template = """Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer.

        {context}

        Question: {question}
        Answer:"""
        PROMPT = PromptTemplate(
        template=prompt_template, input_variables=["context", "question"]
        )
        chain_type_kwargs = {"prompt": PROMPT}

        retriever = vector_store.as_retriever(search_type='similarity', search_kwargs={'k': k})
        chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=retriever, chain_type_kwargs=chain_type_kwargs)

        answer = chain.run(query)
        return answer

    def ask_with_memory(self,vector_store, question, chat_history=[], k=3):
        """
        Given a vector store, input question and a context history use theLLM Chain to return the answer

        Args:
            vector_store: <vector store> a vectore store which stores the embeddings
            question: <str> the input query
            chat_history:  <list> a list containing the history of previous asked question and returned answers
            k: <int> integer determining number of documents to be retreived
        Returns:
            answer: <str> the generated answer
            chat_history: <list> a list containing the history of previous asked question and returned answers
        """
        from langchain.chains import ConversationalRetrievalChain
        from langchain.chat_models import ChatOpenAI

        llm = ChatOpenAI(model='gpt-3.5-turbo', temperature=0)
        retriever = vector_store.as_retriever(search_type='similarity', search_kwargs={'k': k})

        crc = ConversationalRetrievalChain.from_llm(llm, retriever)
        print('question: ',question)
        #print('chat_history: ',chat_history)
        result = crc({'question': question, 'chat_history': chat_history})
        chat_history.append((question, result['answer']))
        return result['answer'], chat_history

# %%
llm_obj  =  LLM_QA()
llm = ChatOpenAI(model='gpt-3.5-turbo', temperature=0)

file_name="data//MFL71521482_new_lower.txt"

chunk_size = 512

data = llm_obj.load_document(file_name)
chunks = llm_obj.chunk_data(data, chunk_size=chunk_size)
print(f'Chunk size: {chunk_size}, Chunks: {len(chunks)}')

tokens, embedding_cost = llm_obj.calculate_embedding_cost(chunks)
print(f'Embedding cost: ${embedding_cost:.4f}')

# creating the embeddings and returning the Chroma vector store
vector_store = llm_obj.create_embeddings(chunks)

queries = open('data/TestCases/combined_data.txt').readlines()
queries = [q.strip() for q in queries]
answers = []
for query in queries:
    chat_history=[]
    answer,chat_history = llm_obj.ask_with_memory(vector_store, query, chat_history=chat_history)
    print('Answer:',answer)
    print('\n')
    #chat_history.append((q, answer))
    answers.append(answer)
# Out:
# Chunk size: 512, Chunks: 296
# Embedding cost: $0.0094
# question:  Why does my washer have very little water in it? How does it wash clothes?
# Answer: Your washer has very little water because it is a high-efficiency washer designed to use a minimum amount of water and energy. Despite the low water volume, the small amount of detergent used is more concentrated in the water, resulting in excellent cleaning performance. The washer rotates the laundry in a way that allows it to use less water while still fully saturating the clothing. It is normal to not see much water during the wash cycle.
#
#
# question:  Please explain why my washer makes such loud banging noises when the water fills up?
# Answer: The loud banging noises that your washer makes while it is filling with water are actually caused by a plumbing issue in your home. When the water valve in the washer shuts off, it can cause the pipes in your home to move or flex, resulting in the loud banging noise. This effect is known as water hammer. To reduce this noise, you can install a water hammer arrestor, which can be purchased separately at a hardware or home improvement store.
#
#
# question:  Reason why washer is making banging noises?
# Answer: The banging noises in your washer could be caused by a problem with the plumbing in your home, known as water hammer. When the water valve in the washer shuts off, it can cause the pipes in your home to move, resulting in a loud banging noise. This can be reduced by installing a water hammer arrestor.
#
#
# question:  why my washing machine is making banging sounds when filling with water?
# Answer: This is actually a problem with the plumbing in your home. When the water valve in the washer shuts off, it can cause pipes in your home to move, resulting in a loud banging noise. This effect, called water hammer, can be reduced by installing an item called a water hammer arrestor. Add-on arrestors can be purchased through your local hardware or home improvement store.
#
#
# question:  Why does my washing machine bang loudly as it fills with water?
# Answer: The loud banging noise during the filling of your washing machine is likely caused by a plumbing issue in your home. When the water valve in the washer shuts off, it can cause the pipes in your home to move, resulting in the banging noise. This is known as water hammer. To reduce this effect, you can install a water hammer arrestor, which can be purchased separately at a hardware or home improvement store.
#
#
# question:  what is the cause of the loud banging noises my washer makes as it fills with water?
# Answer: The cause of the loud banging noises your washer makes as it fills with water is likely water hammer. This occurs when the water valve in the washer shuts off, causing the pipes in your home to move and create a banging noise. It is not a defect in the washer itself. To reduce this effect, you can install a water hammer arrestor, which can be purchased separately at a hardware or home improvement store.
#
#
# question:  may I know the solution for loud banging noises coming from my washing machine?
# Answer: The loud banging noises coming from your washing machine could be due to a problem with the plumbing in your home. When the water valve in the washer shuts off, it can cause pipes in your home to move, resulting in a loud banging noise. This effect, called water hammer, can be reduced by installing a water hammer arrestor. You can purchase add-on arrestors from your local hardware or home improvement store.
#
#
# question:  I need help in resolving the banging noises coming from my washer
# Answer: There could be a few different causes for the banging noises coming from your washer. One possibility is that it is a problem with the plumbing in your home, known as water hammer. When the water valve in the washer shuts off, it can cause pipes in your home to move, resulting in a loud banging noise. This can be reduced by installing a water hammer arrestor, which can be purchased at a local hardware or home improvement store.
#
# Another possibility is that the washer is out of balance. Heavy wash loads or an unbalanced load can cause a thumping sound. Try stopping the washer and redistributing the load to see if that resolves the issue.
#
# If the noise continues after redistributing the load, it's recommended to call for service. There could be other issues causing the banging noises, such as foreign objects in the drum or pump. A professional technician will be able to diagnose and fix the problem.
#
#
# question:  Could you tell me how to stop my washing machine from making loud banging noises?
# Answer: There could be a few reasons why your washing machine is making loud banging noises. One possible cause is water hammer, which is a problem with the plumbing in your home. When the water valve in the washer shuts off, it can cause pipes in your home to move, resulting in a loud banging noise. To reduce this effect, you can install a water hammer arrestor, which can be purchased at your local hardware or home improvement store.
#
# Another possible cause of loud banging noises is an unbalanced wash load. If the load is too heavy or not distributed evenly in the drum, it can cause the washer to become unbalanced and create banging noises. In this case, you can pause the cycle and redistribute the load to ensure it is balanced.
#
# If the banging noises continue after trying these solutions, it may be best to call for service to have a professional inspect and repair your washing machine.
#
#
# question:  what to keep in mind when connecting to the power supply
# Answer: When connecting to the power supply, there are several important things to keep in mind:
#
# 1. Use a properly rated, protected, and sized power circuit to avoid electrical overload.
# 2. Position the appliance near an electrical power supply.
# 3. Before installing or servicing the appliance, disconnect the power cord, house fuse, or circuit breaker.
# 4. Plug the washer into a 120V, 60Hz grounded 3-prong outlet.
# 5. Do not use a worn or damaged power cord or power plug. Replace or repair it immediately to avoid potential hazards.
# 6. Do not modify the power cord and plug provided with the appliance. Avoid damaging it during installation or movement.
# 7. Ensure that the appliance is properly grounded.
# 8. Do not grasp the power cord or touch the appliance controls with wet hands.
# 9. Do not modify or extend the power cord.
# 10. If the electrical supply cord is damaged, it should only be replaced by the manufacturer, its service agent, or a qualified person to avoid hazards.
# 11. Avoid placing oily or greasy clothing, candles, or flammable materials on top of the appliance.
#
#
# question:  what is the procedure to test the washer?
# Answer: To test the washer, follow these steps:
#
# 1. Ensure that the washer is properly installed.
# 2. Load the washer with 6 thick bath towels, approximately 6 pounds in weight.
# 3. Press the power button to turn on the washer.
# 4. Select the desired cycle, such as rinse+spin.
# 5. Press the start/pause button to begin the wash cycle.
# 6. Check that water is being supplied to the washer, and that it does not rock or vibrate excessively during operation.
# 7. Make sure the washer drains well during the spin cycle.
# 8. Once the cycle is finished, a melody will sound. Immediately remove the clothing from the washer to reduce wrinkling.
# 9. Check around the door seal for any small items that may be caught.
# 10. Note that if the temperature or water level inside the machine is too high, the door will lock and cannot be opened.
#
# Remember to press the start/pause button within a certain time to avoid the washer shutting off and losing all settings.
#
#
# question:  May I know how I can use non skid pads?
# Answer: To use non-skid pads, follow these steps:
#
# 1. Clean the floor: Make sure the floor is clean and free of any debris or moisture. Use a dry rag to remove any foreign objects or moisture that may cause the pads to slip.
#
# 2. Place the adhesive side down: Take the non-skid pad and place the adhesive side (side with the sticky surface) on the floor. Make sure it is positioned where you want to install the washer.
#
# 3. Install under leveling feet: For maximum effectiveness, it is recommended to install the non-skid pads under the front leveling feet of the washer. If it is difficult to access the front feet, you can place the pads under the back leveling feet instead.
#
# 4. Remove backing: If the non-skid pads have a protective backing, remove it to expose the adhesive side.
#
# 5. Recheck levelness: After placing the washer in the installation area, recheck its levelness. Gently push or rock the top edges of the washer to ensure it does not rock. If it rocks, adjust the level again.
#
# Using non-skid pads can help prevent excessive vibration and movement of the washer, reducing the risk of malfunction, noise, and vibration. It is especially useful when installing the washer on a slippery surface.
#
#
# question:  I want to use non skid pads
# Answer: To use non-skid pads, follow these steps:
#
# 1. Clean the floor where you plan to place the non-skid pads. Use a dry rag to remove any foreign objects or moisture. If there is moisture remaining, the pads may slip.
#
# 2. Place the adhesive side (side C) of the non-skid pad on the floor. Make sure it is securely attached.
#
# 3. It is most effective to install the non-skid pads under the front leveling feet of the washer. However, if it is difficult to place them under the front feet, you can place them under the back leveling feet instead.
#
# 4. After placing the washer in the installation area, recheck its levelness. Gently push or rock the top edges of the washer to ensure it does not rock. If it does rock, level the washer again.
#
# Using non-skid pads can help prevent excessive vibration and ensure proper functioning of the washer.
#
#
# question:  Things to remember when choosing a proper location
# Answer: When choosing a proper location for the appliance, there are a few things to remember:
#
# 1. The location should be within the province or territory in which you reside, unless both you and the manufacturer agree to another location or telephonic arbitration.
#
# 2. The appliance should be installed on a firm and level floor to ensure stability and proper functioning.
#
# 3. Refer to the installation instructions provided with the appliance for detailed grounding procedures. It is important to follow these instructions to ensure safety.
#
# 4. If you are moving the appliance to a new location, it is recommended to have it checked and reinstalled by qualified service personnel to ensure proper installation and functioning.
#
# 5. Moving or installing the appliance may require two or more people to ensure safe handling.
#
# 6. Avoid installing the appliance in humid spaces, as this can potentially damage the appliance or affect its performance.
#
#
# question:  Things to do before leveling the washer
# Answer: Before leveling the washer, make sure to position it in its final location. Take care not to pinch, strain, or crush the water and drain hoses. If you have a carpenter's level, you can use it to check if the washer is level. The slope beneath the washer should not exceed 1 inch, and all 4 leveling feet must rest firmly on the floor.
#
#
# question:  Is there anything I need to know when connecting to the power supply
# Answer: Yes, there are several important things to keep in mind when connecting your appliance to the power supply:
#
# 1. Make sure to connect the appliance to a properly rated, protected, and sized power circuit. This will help avoid electrical overload and potential hazards.
#
# 2. Position the appliance near an electrical power supply to ensure easy access to the outlet.
#
# 3. Before installing or servicing the appliance, always disconnect the power cord, house fuse, or circuit breaker to ensure your safety.
#
# 4. The power cord of the appliance is equipped with a 3-prong (grounding) plug. It should be plugged into a standard 3-prong (grounding) wall outlet. This grounding feature minimizes the possibility of electric shock.
#
# 5. Do not use a worn or damaged power cord or power plug. If you notice any issues, replace or repair it immediately. Failure to do so may result in serious consequences such as death, fire, electric shock, or malfunction.
#
# 6. Do not modify the power cord and plug provided with the appliance. Additionally, avoid damaging the cord during installation or when moving the appliance. Any damage to the cord may lead to severe risks such as death, fire, electric shock, or malfunction.
#
# 7. It is crucial to ensure that the appliance is properly grounded. Connect it to a grounded outlet that conforms to the rating specified. Failure to do so may result in fire, electric shock, or malfunction.
#
# 8. Never damage or cut off the ground prong of the power cord. Doing so can cause serious consequences such as death, fire, electric shock, or product malfunction.
#
#
# question:  Draining the laundry tub
# Answer: To drain the laundry tub, follow these steps:
#
# 1. Clip the end of the drain hose into the elbow bracket.
# 2. Connect the elbow bracket within 4 inches (10 cm) of the end of the drain hose. Make sure not to extend the hose more than 4 inches beyond the elbow bracket to prevent the spread of mold or microorganisms to the inside of the washer.
# 3. Hang the end of the drain hose over the side of the laundry tub.
# 4. Use the provided tie strap to secure the drain hose in place.
#
# This will allow the water to drain from the washer into the laundry tub.
#
#
# question:  How to Level the Washing machine?
# Answer: To level the washing machine, follow these steps:
#
# 1. Position the washer in its final location, taking care not to pinch, strain, or crush the water and drain hoses.
# 2. If you have a carpenter's level, use it to check that the washer is level. The slope beneath the washer should not exceed 1 inch, and all 4 leveling feet must rest firmly on the floor.
# 3. Adjust the leveling feet by turning all 4 feet in one direction to raise or lower the washer.
# 4. Check the level again by gently pushing or rocking the top edges of the washer. If it rocks, readjust the leveling feet.
# 5. Once the washer is level, tighten the locknuts by turning them counterclockwise and tightening them.
#
# Remember, it's important to ensure the washer is level to prevent any issues during operation.
#
#
# question:  How can I drain the laundry tub?
# Answer: To drain the laundry tub, you can follow these steps:
#
# 1. Clip the end of the hose into the elbow bracket.
# 2. Connect the elbow bracket within 4 inches (10 cm) of the end of the drain hose. Make sure the hose is not extended more than 4 inches beyond the elbow bracket to prevent the spread of mold or microorganisms to the inside of the washer.
# 3. Hang the end of the drain hose over the side of the laundry tub.
# 4. Use the provided tie strap to secure the drain hose in place.
#
# This should allow the water to drain from the laundry tub.
#
#
# question:  what does the back view of the product look like?
# Answer: The back view of the product includes water inlets, shipping bolts, power cord, and drain hose.
#
#
# question:  I'm curious about the product components
# Answer: The information provided does not specifically mention the product components. However, it states that damage or failure caused by the use of unauthorized parts, accessories, components, or any other products is not covered under warranty. Therefore, it is important to use authorized components for the product to ensure warranty coverage.
#
#
# question:  Please provide the description of the product
# Answer: I'm sorry, but I don't have enough information to provide a description of the product.
#
#
# question:  Please describe the accessories for me.
# Answer: I'm sorry, but the given context does not provide any information about the accessories for the appliance.
#
#
# question:  Tell me about the front of the product
# Answer: I'm sorry, but I don't have enough information to answer your question. Could you please provide more specific details about the product you are referring to?
#
#
# question:  What does the front of the product look like?
# Answer: I'm sorry, but I don't have that information.
#
#
# question:  give me the option and features of my washing machine
# Answer: Based on the provided context, the options and features of your washing machine include:
#
# 1. Wash Temperature Adjustment: You can adjust the wash temperature according to your preference or the requirements of the laundry.
#
# 2. Spin Speed Adjustment: You can adjust the spin speed to control how fast the drum spins during the cycle.
#
# 3. Soil Level Settings: You can select the soil level setting based on the level of dirtiness of your laundry.
#
# 4. Time and Status Display: The display shows the current settings, time remaining, and the status of the cycle.
#
# 5. AI DD Indicator: This indicator lights up when the normal cycle is selected and operated, indicating that the appropriate drum rotation actions are being performed based on load sensing.
#
# 6. Cycle Status Indicators: These indicators show the progress of the selected cycle.
#
# 7. Option and Extra Function Buttons: These buttons allow you to select additional cycle options and activate special functions by pressing and holding the button for 3 seconds.
#
# 8. Extra Rinse: This option adds an extra rinse to the selected cycle, ensuring the removal of detergent or bleach residue from fabrics.
#
# 9. Heavy Soil: This option provides more power than the standard cycle, allowing you to wash heavily soiled laundry effectively.
#
# Please note that the specific options and features may vary depending on the model and brand of your washing machine. It is recommended to refer to the user manual or contact the manufacturer for detailed information about your specific washing machine.
#
#
# question:  I want to know the components of the product
# Answer: I'm sorry, but I don't have enough information to answer your question. Could you please provide more specific details about the product you are referring to?
#
#
# question:  list the features of product
# Answer: I'm sorry, but I don't have enough information to provide a list of features for a specific product. Could you please provide more details or specify the product you are referring to?
#
#
# question:  Let me know what the accessories are
# Answer: The included accessories for the appliance are non-skid pads, hole caps, a wrench, a tie strap, and an elbow bracket for securing the drain hose. The required accessories, which are sold separately, are hot and cold water hoses.
#
#
# question:  Provide me instructions in removing the mineral buildup, please.
# Answer: To remove mineral buildup from your washer, follow these steps:
#
# 1. Use a descaler: Start by using a descaler specifically designed for washing machines. Follow the manufacturer's instructions on how to use it. Typically, you will need to pour the descaler into the detergent dispenser or directly into the drum.
#
# 2. Clean the drum: After using the descaler, run the washer on the tub clean cycle. This cycle is specifically designed to clean the drum and remove any remaining mineral buildup. Refer to your washer's manual for instructions on how to run the tub clean cycle.
#
# 3. Clean the stainless steel drum: If you notice any mineral scale or spots on the stainless steel drum, you can use a soft cloth soaked in stainless steel cleaner to remove them. Avoid using steel wool or abrasive cleaners, as they can damage the drum.
#
# 4. Clean the filters: If your washer has filters, carefully remove them and clean them according to the manufacturer's instructions. Be cautious not to damage the filters while cleaning. Rinse them thoroughly and press them back into place.
#
# 5. Flush and reattach water hoses: Before reattaching the water inlet hoses, flush them by running several gallons of water through them into a bucket or drain. It's best to do this with the faucets wide open for maximum flow. Once flushed, reattach the water hoses securely.
#
# By following these steps, you can effectively remove mineral buildup from your washer and help extend its lifespan.
#
#
# question:  What should I do if I don't use the washer for extended period of time?
# Answer: If you don't use the washer for an extended period of time and it is in an area that could be exposed to freezing temperatures, you should follow these steps to protect the washer from damage:
#
# 1. Make sure the drum is empty before proceeding.
# 2. Turn off the washer and unplug the power cord.
# 3. Turn off the water faucets.
# 4. Disconnect the water inlet hoses and drain any water from them.
# 5. Plug the power cord into a properly grounded electrical outlet.
#
# By following these steps, you can ensure that your washer is protected during periods of non-use.
#
#
# question:  I wish to wash the product's outside.
# Answer: To clean the exterior of the washer, you can follow these steps:
#
# 1. Use a damp cloth to wipe both the outside and inside of the door.
# 2. Dry the surfaces with a soft cloth.
# 3. Immediately wipe off any spills on the exterior with a damp cloth.
# 4. Avoid touching the surface or display with sharp objects.
#
# By following these instructions, you can properly clean the outside of your washer.
#
#
# question:  Solution for unfreezing the drain hose
# Answer: To unfreeze the drain hose, follow these steps:
#
# 1. Pour hot water into the washer drum and close the door.
# 2. Wait for 1-2 hours to allow the hot water to thaw the frozen drain hose.
# 3. Press the power button to turn on the appliance.
# 4. Press the spin button to activate the spin-only cycle for draining and spinning.
# 5. Press the start/pause button to ensure that the water drains properly.
#
# If the drain hose is still frozen after following these steps, you may need to seek further assistance or consult the appliance's manual for additional troubleshooting options.
#
#
# question:  how can I clean the drain pump filter?
# Answer: To clean the drain pump filter, follow these steps:
#
# 1. Turn off the washer and unplug the power cord for safety.
# 2. Open the drain pump filter cover, usually located at the front or bottom of the washer.
# 3. If there is any remaining water in the drum, drain it by unclipping the drain hose and removing the plug from the drain hose. You can use a bucket to catch the water.
# 4. Remove the pump filter by twisting it counterclockwise.
# 5. Clean the pump filter and the opening thoroughly, removing any dirt or debris.
# 6. Reassemble the plug onto the drain hose and reclip the drain hose securely.
# 7. Insert the drain pump filter back into its place and twist it clockwise to secure it.
# 8. Close the drain pump filter cover.
# 9. Once everything is reassembled, you can plug in the power cord and turn on the washer.
#
# Remember, it is important to periodically clean the drain pump filter to prevent clogging and ensure proper drainage.
#
#
# question:  Please let me know if leaving the washer door open is recommended.
# Answer: Yes, leaving the washer door open after use is recommended. It allows air to circulate and helps dry the drum, which can prevent odors from developing.
#
#
# question:  please provide the instructions to clean the door seal
# Answer: To clean the door seal, follow these steps:
#
# 1. Wear rubber gloves and protective goggles for safety.
# 2. Dilute 3/4 cup (177 ml) of liquid chlorine bleach in 1 gallon (3.8 l) of water.
# 3. Soak a sponge or a soft cloth in the diluted bleach solution.
# 4. Wipe all around the door seal with the sponge or cloth.
# 5. Make sure to wipe away any dirt or build-up.
# 6. After cleaning, wipe up any moisture with a dry towel or cloth.
# 7. Leave the door open to allow the door seal to dry completely.
#
# Remember, do not clean the door seal with undiluted bleach as it may cause malfunction of the door seal and washer parts. Always dilute the bleach with water before using it.
#
#
# question:  tips to clean the dispenser
# Answer: To clean the dispenser drawer, follow these steps:
#
# 1. Turn off the washer and unplug the power cord for safety.
# 2. Pull the detergent dispenser drawer straight out until it stops.
# 3. Remove any remaining laundry products from the compartments.
# 4. Rinse the dispenser drawer under running water to remove any residue or build-up.
# 5. Use a soft brush or cloth to scrub the compartments and remove any stubborn residue.
# 6. If necessary, you can use a mild detergent or vinegar solution to help remove any stubborn stains or odors.
# 7. Rinse the dispenser drawer thoroughly to remove any cleaning solution.
# 8. Wipe the drawer dry with a clean cloth.
# 9. Gently push the detergent dispenser drawer back into place until it clicks or locks into position.
# 10. Plug in the power cord and turn on the washer.
#
# Remember to clean the detergent dispenser drawer once or twice a month to prevent the build-up of residue.
#
#
# question:  How can I clean around the product door?
# Answer: To clean around the product door, you can follow these steps:
#
# 1. Prepare a solution by diluting 3/4 cup (177 ml) of liquid chlorine bleach in 1 gallon (3.8 l) of water.
# 2. Put on rubber gloves and protective goggles for safety.
# 3. Dip a sponge or a soft cloth into the diluted bleach solution.
# 4. Wipe around the door seal, making sure to clean any dirt or buildup.
# 5. After cleaning, use a dry towel or cloth to wipe up any moisture.
# 6. To allow the door seal to dry completely, leave the door open.
#
# Remember, do not use undiluted bleach as it may cause malfunction of the door seal and washer parts.
#
#
# question:  Tell me how to store the washer?
# Answer: To store the washer, follow these steps:
#
# 1. Make sure the drum is empty before proceeding.
# 2. Turn off the washer and unplug the power cord.
# 3. Turn off the water faucets.
# 4. Disconnect the water inlet hoses and drain any water from them.
# 5. Plug the power cord into a properly grounded electrical outlet.
# 6. Store and install the appliance in a location where it will not be exposed to temperatures below freezing or outdoor weather conditions.
#
# It is important to properly ground the washer to conform with all governing codes and ordinances to avoid serious injury, fire, electric shock, or death.
#
#
# question:  What to keep in mind before using the washer?
# Answer: Before using the washer, here are some important things to keep in mind:
#
# 1. Check and empty pockets: Make sure to remove any items like paper clips, coins, matches, or other objects that could potentially damage the clothing or the washer.
#
# 2. Close zippers and hooks: Ensure that all zippers and hooks are securely closed to prevent snagging or tangling of clothes during the wash cycle.
#
# 3. Tie drawstrings: If your clothes have drawstrings, it's a good idea to tie them to prevent them from getting tangled with other items.
#
# 4. Pretreat heavily stained areas: If you have heavily stained areas on your clothes, it's recommended to pretreat them before washing for better stain removal results.
#
# 5. Brush off heavy soil, dust, and hair: Before loading your clothes into the washer, brush off any excess dirt, sand, or hair from the items. This helps prevent abrasion of other fabrics and ensures better wash performance.
#
# 6. Load clothes loosely and do not overfill: It's important to load clothes loosely in the drum and avoid overfilling it. Clothes need room to circulate in order to get clean effectively. The drum should not be tightly packed, and the door of the washer should be able to close easily.
#
# 7. Combine large and small items: When loading the washer, it's recommended to combine large and small items. Start by loading the large items first, but ensure that they do not exceed half of the total load.
#
# 8. Do not reach into the washer while it's in motion: It's crucial to avoid reaching into the washer if the tub or drum, agitator, or any interior parts are moving. Before loading, unloading, or adding items, press the start/pause button and allow the tub or drum to come to a complete stop before reaching inside.
#
#
# question:  what must I do before I fill the washer?
# Answer: Before filling the washer, you should sort your laundry by fabric type, soil level, color, and load size as needed. Additionally, if you are using single-use detergent packs, gel, or tablet detergents, you should place them in the drum before loading the laundry. Finally, you can add the proper amount of HE (high-efficiency) detergent to the detergent dispenser and, if desired, add bleach or fabric softener to the appropriate areas of the dispenser drawer.
#
#
# question:  How to use single use detergent?
# Answer: To use single-use detergent packs, gel, or tablet detergents, place them directly in the drum of the washing machine before loading your laundry. Do not place these detergents in the dispenser. It is important to note that you should only use one single-use detergent pack per wash. Using more than one pack can cause oversudsing and unsatisfactory performance. If you notice detergent residue on your fabrics, you can reduce the detergent amount or add an extra rinse. To add an extra rinse, select the extra rinse option on your washing machine.
#
#
# question:  Things to remember before using the washing machine
# Answer: 1. Check and empty pockets to prevent damage to clothing and the washer.
# 2. Close zippers and hooks, and tie drawstrings to prevent snagging or tangling of clothes.
# 3. Pretreat heavily stained areas for best results.
# 4. Brush off heavy soil, dust, and hair from items before washing.
# 5. Load clothes as shown for best performance.
# 6. Do not place objects on top of the appliance.
# 7. Turn off water faucets and unplug the appliance if left for an extended period.
# 8. Always follow fabric care instructions provided by the garment manufacturer.
# 9. Use fabric softeners or products to eliminate static as recommended.
# 10. Do not combine laundry products unless specified on the label.
# 11. Do not touch draining water, as it may be hot.
# 12. Load clothes loosely and do not overfill the drum.
# 13. Combine large and small items in the drum, with large items loaded first.
# 14. The drum should not be tightly packed, and the door must close easily.
# 15. The washer will not fill or operate with the door open.
#
#
# question:  how can I control my washer remotely?
# Answer: To control your washer remotely, you can use a smartphone and the LG ThinQ application. First, make sure your washer is connected to your home Wi-Fi network. You will see the "f" icon lit on the control panel when it is connected. Then, press and hold the delay wash button on the washer for 3 seconds to connect it to the LG ThinQ application. Once connected, you can use the application to control and monitor your washer remotely.
#
#
# question:  can you please show me how to use fabric care labels?
# Answer: To use fabric care labels, follow these steps:
#
# 1. Check the label on your clothing item for any specific instructions or symbols. The label should provide information on how to wash and care for the fabric.
#
# 2. Determine the appropriate washing method based on the label instructions. It may indicate whether the item should be hand washed or machine washed.
#
# 3. If machine washing is recommended, adjust the cycle and option selections on your washing machine according to the label instructions. This may include using a normal cycle, a perm press/wrinkle resistant setting, or a gentle/delicate setting.
#
# 4. Pay attention to the water temperature specified on the label. It may indicate whether to use hot, warm, or cold/cool water.
#
# 5. Follow any additional directions provided on the label. This may include avoiding wringing the item, using fabric softeners or products to eliminate static as recommended, and not combining laundry products unless specified.
#
# 6. Before washing, make sure to check and empty pockets, close zippers and hooks, and tie drawstrings to prevent any damage or tangling of clothes.
#
# 7. If the label advises pretreating heavily stained areas, do so before washing for the best results.
#
# 8. Brush off any heavy soil, dust, or hair from the item before washing to prevent abrasion and ensure better wash performance.
#
# 9. Load the clothes into the washing machine as shown in the label instructions. Avoid pressing down on items while stacking them in the drum.
#
# Remember to always follow the fabric care instructions supplied by the garment manufacturer for the best care and longevity of your clothing.
#
#
# question:  Let me know the features of control panel
# Answer: The control panel features a power on/off button. You can press this button to turn the washer on or off. If you press this button during a cycle, it will cancel that cycle and any load settings will be lost. The door will unlock after a brief pause. Additionally, there is a control lock feature that can be activated or deactivated by pressing and holding the designated button for 3 seconds.
#
#
# question:  what should I do before sorting my laundry
# Answer: Before sorting your laundry, you should check and empty pockets to remove any items that could potentially damage clothing or the washer. You should also close zippers and hooks, and tie drawstrings to prevent snagging or tangling of clothes. Additionally, it is recommended to brush off heavy soil, dust, and hair from items before washing to prevent poor wash performance.
#
#
# question:  give me instructions to select the add item function
# Answer: To select the add item function on your washing machine, follow these steps:
#
# 1. Turn on the power to the washing machine.
# 2. Locate the "Add Item" button on the control panel.
# 3. Start a wash cycle by selecting the desired cycle and pressing the start/pause button.
# 4. While the wash cycle is running, press the "Add Item" button.
# 5. The cycle will pause, and the door will unlock.
# 6. Open the door to add garments or remove any foreign objects like coins or keys.
# 7. Close the door securely.
# 8. Press the start/pause button to resume the cycle.
# 9. The cycle will continue automatically.
#
# Remember, if you turn off the power, the add item function will not reset. You must deactivate this function before accessing any other options or functions.
#
#
# question:  please guide me in using the pre-wash option
# Answer: To use the pre-wash option, follow these steps:
#
# 1. Load your heavily soiled or stained clothing into the washer.
# 2. Add the appropriate amount of liquid detergent for the main wash cycle to the liquid detergent cup accessory in the main wash dispenser.
# 3. If you have already put the detergent directly in the drum, it is recommended to not use the pre-wash option as the detergent may be washed away, reducing the washing performance.
# 4. Press the pre-wash button on your washer's control panel. This will activate the pre-wash cycle, which typically runs for about 15-17 minutes.
# 5. Once the pre-wash cycle is complete, the main wash cycle will begin automatically.
# 6. Remember that the amount of detergent added for the pre-wash option should be half the amount recommended for the main wash cycle. For example, if the main wash cycle requires one measure of detergent, add only half a measure for the pre-wash option.
#
# Please consult your washer's manual for specific instructions and any additional information related to the pre-wash option.
#
#
# question:  What guidelines should I follow before operating the product?
# Answer: Before operating the product, you should adhere to all industry recommended safety procedures, including the use of long-sleeved gloves and safety glasses. Additionally, you should never attempt to operate the appliance if it is damaged, malfunctioning, partially disassembled, or has missing or broken parts. This includes a damaged cord or plug. It is important to properly install the appliance as described in the manual before use.
#
#
# question:  guidelines for using the product safely
# Answer: To use the product safely, please follow these guidelines:
#
# 1. Before using the appliance, carefully read and save the instruction manual.
#
# 2. Adhere to all industry recommended safety procedures, such as wearing long-sleeved gloves and safety glasses.
#
# 3. Do not attempt to operate the appliance if it is damaged, malfunctioning, partially disassembled, or has missing or broken parts. This includes a damaged cord or plug.
#
# 4. Properly install the appliance as described in the manual before use.
#
# 5. Follow all installation instructions to reduce the risk of severe injury or death.
#
# 6. Pay attention to all safety messages provided. They will inform you of potential hazards, how to reduce the chance of injury, and what may happen if the instructions are not followed.
#
# 7. Use the appliance only for its intended purpose.
#
# 8. If the product has been submerged in water, sitting in standing water, or waterlogged, do not come in contact with it. Immediately contact an LG Electronics customer information center for instructions before resuming use.
#
# Remember, following these guidelines is crucial for your safety and the proper functioning of the appliance.
#
#
# question:  how to safely install the product?
# Answer: To safely install the product, follow these steps:
#
# 1. Choose a firm and level floor for installation.
# 2. Adhere to all industry recommended safety procedures, such as wearing long-sleeved gloves and safety glasses.
# 3. Ensure that the appliance is not damaged, malfunctioning, partially disassembled, or missing any parts, including a damaged cord or plug. Do not attempt to operate it under these conditions.
# 4. Properly install the appliance as described in the manual before use.
# 5. Store and install the appliance in a location where it will not be exposed to temperatures below freezing or outdoor weather conditions.
# 6. Note that the appliance is not designed for maritime use or mobile installations in vehicles like RVs, trailers, or aircraft.
# 7. Keep packaging materials out of the reach of children, as they can be dangerous and pose a risk of suffocation.
#
#
# question:  please display the safety messages
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 1.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600).
# Answer: I'm sorry, but as a text-based AI, I am unable to display any visual content. However, I can provide you with the safety messages in text format.
#
#
# question:  what to avoid when using the product
# Answer: To avoid any potential hazards or damage when using the product, you should:
#
# 1. Follow all instructions provided in the product's owner's manual.
# 2. Use the product only for normal household use and avoid using it for commercial or industrial purposes.
# 3. Use only approved and authorized accessories, components, and cleaning products recommended by the manufacturer.
# 4. Avoid using the product in locations or settings that are not outlined in the product's owner's manual, such as commercial offices, recreational facilities, or vehicles.
# 5. Ensure that the product is installed properly according to the instructions in the owner's manual.
# 6. Do not attempt to remove or reinstall the product if it is in an inaccessible location or if you are not familiar with the proper procedure.
# 7. Do not use the product in a way that is not intended or recommended by the manufacturer.
#
# Following these guidelines will help reduce the risk of injury, damage to the product, and ensure the product's proper functioning.
#
#
# question:  washing machine maintenance guidelines for safety
# Answer: Here are some washing machine maintenance guidelines for safety:
#
# 1. Before starting a wash cycle, always check and empty the pockets of your clothes. Items like paper clips, coins, matches, and other objects can damage the clothing and the washer.
#
# 2. Close zippers and hooks, and tie drawstrings to prevent snagging or tangling of clothes during the wash cycle.
#
# 3. If you have heavily stained areas on your clothes, it's best to pretreat them before washing for better results.
#
# 4. Brush off any heavy soil, dust, or hair from your items before putting them in the washer. Excess dirt or sand can abrade other fabrics and affect the wash performance.
#
# 5. When loading the clothes into the washer, follow the recommended guidelines for best performance. Avoid pressing down on items while stacking them in the drum.
#
# 6. Do not place any objects on top of the washing machine as it can cause damage or interfere with its operation.
#
# 7. If you're planning to leave the appliance unused for an extended period, such as during vacations, make sure to turn off the water faucets and unplug the machine for safety.
#
# 8. Always follow the fabric care instructions provided by the garment manufacturer to ensure proper washing and avoid damaging your clothes.
#
# 9. Use fabric softeners or products to eliminate static only as recommended by the manufacturer. Avoid combining laundry products unless specified on the label.
#
# 10. Avoid touching draining water, as it may be hot and can cause burns.
#
# 11. Regularly check the inside of the washing machine for any foreign objects that may have been left behind, as they can cause damage during the wash cycle.
#
# 12. Avoid leaving water, bleach, or other liquids sitting in the drum for extended periods, as it can lead to corrosion, mildew, or odors.
#
# 13. Do not use the washing machine to dry unwashed items. It is designed for washing only and using it for drying purposes can cause damage.
#
#
# question:  Could you provide recommendations for grounding, please
# Answer: To ensure proper grounding, please follow these recommendations:
#
# 1. Check with a qualified electrician or service personnel if you are unsure whether the appliance is properly grounded.
# 2. Do not modify the plug provided with the appliance. If it does not fit the outlet, have a proper outlet installed by a qualified electrician.
# 3. Refer to the installation instructions for detailed grounding procedures. These instructions are included with the appliance for the installer's reference.
# 4. If you are moving the appliance to a new location, have it checked and reinstalled by qualified service personnel.
# 5. It is important to have the appliance grounded to reduce the risk of electric shock in case of malfunction or breakdown.
# 6. The appliance should be plugged into an appropriate outlet that is installed and grounded according to local codes and ordinances.
#
# Please note that these recommendations are general guidelines. For specific instructions related to your appliance, refer to the manufacturer's documentation or consult a qualified electrician.
#
#
# question:  tips for grounding the appliance
# Answer: To properly ground the appliance, follow these tips:
#
# 1. Read the installation instructions provided with the appliance. They should include detailed grounding procedures specific to the appliance.
#
# 2. Ensure that the appliance is installed by qualified service personnel. They will have the knowledge and expertise to properly ground the appliance.
#
# 3. When moving or installing the appliance, make sure to have at least two people involved. This will ensure safe handling and prevent accidents.
#
# 4. Do not install the appliance in humid spaces. Moisture can increase the risk of electrical shock and damage to the appliance.
#
# 5. The appliance should be plugged into an appropriate outlet that is installed and grounded in accordance with local codes and ordinances. If you are unsure about the grounding, consult a qualified electrician or service personnel.
#
# 6. Do not modify the plug provided with the appliance. If the plug does not fit the outlet, have a proper outlet installed by a qualified electrician.
#
# Remember, proper grounding is essential for reducing the risk of electric shock and ensuring the safe operation of the appliance.
#
#
# question:  what should I keep in mind while grounding my product?
# Answer: When grounding your product, there are a few important things to keep in mind:
#
# 1. Ensure that the appliance is plugged into an appropriate outlet that is installed and grounded according to local codes and ordinances.
# 2. Do not modify the plug provided with the appliance. If it does not fit the outlet, have a proper outlet installed by a qualified electrician.
# 3. Check with a qualified electrician or service personnel if you are unsure whether the appliance is properly grounded.
# 4. Do not damage or cut off the ground prong of the power cord. This can result in serious consequences such as death, fire, electric shock, or product malfunction.
#
# Following these guidelines will help reduce the risk of electric shock and ensure the safe operation of your appliance.
#
#
# question:  give me the caution notes to follow while using the product
# Answer: Caution:
# 1. Always read and follow all safety messages provided in the manual and on the appliance.
# 2. Do not operate the appliance if it is damaged, malfunctioning, partially disassembled, or has missing or broken parts, including a damaged cord or plug.
# 3. Adhere to all industry recommended safety procedures, including the use of long-sleeved gloves and safety glasses during installation.
# 4. Properly install the appliance as described in the manual before use.
# 5. Failure to follow installation instructions may result in severe injury or death.
# 6. Take caution to reduce the chance of injury or damage to the product by following all instructions provided.
#
#
# question:  tell me the spin speed of my product
# Answer: The spin speed of your product can be adjusted according to your preference. The default spin speed is set to "ex high," but you have the option to select any available spin speed.
#
#
# question:  I want to know the weight of my product
# Answer: The net weight of the product is 154.3 lb (70 kg).
#
#
# question:  what is the maximum water pressure?
# Answer: The maximum water pressure for this product is 120 psi (827 kpa).
#
#
# question:  please give the dimensions for my product
# Answer: The dimensions of the product are 24'' x 33 1/2'' x 22 1/4'' (60 cm x 85 cm x 56.5 cm).
#
#
# question:  what is the maximum spin speed of my washer?
# Answer: The maximum spin speed of your washer is not specified in the given context.
#
#
# question:  maximum depth with door open for my product
# Answer: The maximum depth with the door open for the product model WM1455H*A is 43 1/4'' (110 cm).
#
#
# question:  what is the minimum water pressure?
# Answer: I don't know the specific minimum water pressure required. It would be best to consult the manufacturer's guidelines or contact a plumber for more information.
#
#
# question:  maximum water pressure for my washing machine
# Answer: The maximum water pressure for the washing machine is 120 psi (827 kpa).
#
#
# question:  I'd want to know about the voltage requirements for my product
# Answer: The voltage requirements for the product are 120 volts at 60 hertz.
#
#
# question:  what is the weight of my product?
# Answer: The weight of the product is 154.3 lb (70 kg).
#
#
# question:  what is the functionality of LG Thinq application?
# Answer: The LG Thinq application allows users to remotely control and monitor their LG appliances that have a wireless LAN module. It enables features such as remote start, downloading new and specialized cycles, monitoring energy consumption, and accessing the Tub Clean Coach feature to track the remaining cycles before running a tub clean. Additionally, the application can be used to diagnose issues with Wi-Fi equipped appliances by transmitting troubleshooting data to a smartphone.
#
#
# question:  how do I use the audible diagnosis feature
# Answer: To use the audible diagnosis feature, follow these steps:
#
# 1. Launch the LG ThinQ application on your smartphone.
# 2. Select the "Smart Diagnosis" feature from the menu.
# 3. Follow the instructions provided in the LG ThinQ application.
# 4. Press the power button on your appliance to turn it on.
# 5. Do not press any other buttons on the appliance.
# 6. Place the mouthpiece of your smartphone close to the "C" or "D" logo on the appliance.
# 7. Press and hold the temperature button on the appliance for 3 seconds or until you hear audible tones.
# 8. Hold the smartphone's mouthpiece to the logo until the data transfer is complete.
# ...
# 8. Hold the smartphone's mouthpiece to the logo until the data transfer is complete.
# 9. Keep the smartphone in place until the data transfer has finished. The remaining time for data transfer will be displayed.
# 10. After the data transfer is complete, the diagnosis will be displayed in the LG ThinQ application.
#
# Note: It is important not to move the smartphone while the tones are being transmitted for best results.
#
# Please exercise caution and follow all safety instructions to avoid any potential hazards or injuries.
#
#
# question:  tell me about the FCC RF regulations?
# Answer: The FCC (Federal Communications Commission) has set regulations regarding RF (radio frequency) radiation exposure. These regulations are in place to ensure that the equipment complies with the radiation exposure limits for an uncontrolled environment. The equipment should not be co-located or operated in conjunction with any other antenna or transmitter.
#
# To comply with RF exposure compliance, the equipment should be installed and operated with a minimum distance of 20 cm (7.8 inches) between the antenna and the user's body. Users must also follow the specific operating instructions provided.
#
# Additionally, the FCC notice states that the equipment has been tested and found to comply with the limits for a class B digital device, according to Part 15 of the FCC rules. These limits are designed to provide reasonable protection against harmful interference in a residential installation. It is important to install and use the equipment in accordance with the instructions to avoid causing harmful interference to radio communications. However, there is no guarantee that interference will not occur.
#
#
# question:  I want to use the washer remotely, what is the procedure?
# Answer: To use the washer remotely, follow these steps:
#
# 1. Put the laundry in the drum and add detergent to the detergent dispenser drawer. If desired, add bleach or fabric softener to the appropriate areas of the dispenser.
# 2. Press the power button to turn on the washer.
# 3. Press and hold the remote start button for 3 seconds to enable the remote control function.
# 4. Use a smartphone to control your washer remotely. You can also monitor the cycle operation to know how much time is left in the cycle.
# 5. For more detailed information on using the smart functions and connecting the washer to the LG ThinQ application, refer to the manual or instructions provided.
#
#
# question:  What does the FCC notice cover?
# Answer: The FCC notice covers the transmitter module contained in the product.
#
#
# question:  steps to follow when using the audible diagnosis
# Answer: To use the audible diagnosis method, follow these steps:
#
# 1. Launch the LG ThinQ application on your smartphone.
# 2. Select the "Smart Diagnosis" feature from the menu.
# 3. Follow the instructions provided in the LG ThinQ application.
# 4. Press the power button on your appliance to turn it on.
# 5. Do not press any other buttons on the appliance.
# 6. Place the mouthpiece of your smartphone close to the "C" or "D" logo on the appliance.
# 7. Press and hold the temperature button on the appliance for 3 seconds or until you hear audible tones.
# 8. Hold the smartphone's mouthpiece to the logo until the data transfer is complete.
# 9. Keep the smartphone in place until the data transfer has finished (the remaining time will be displayed).
# 10. After the data transfer is complete, the diagnosis will be displayed in the LG ThinQ application.
#
# Note: It is important not to move the smartphone while the tones are being transmitted for best results.
#
#
# question:  OE appears on screen.
# Answer: I'm sorry, but I don't have enough information to understand what "OE" refers to in this context. Could you please provide more details or clarify your question?
#
#
# question:  bleach was added directly to the wash load, is this why there is staining?
# Answer: Yes, adding bleach directly to the wash load in the drum can cause staining. It is recommended to always use the dispensers to ensure that laundry products, including bleach, are properly dispensed at the right time in the cycle.
#
#
# question:  I am getting UE on the machine. Can I know the reason? Tell me also how to fix this up?
# Answer: The UE error message on your machine indicates an unbalanced load. This can occur when the laundry inside the machine is unevenly distributed. To fix this issue, try the following steps:
#
# 1. Open the machine and redistribute the laundry evenly.
# 2. Remove any large or heavy items that may be causing the imbalance.
# 3. Restart the machine and see if the error message disappears.
#
# If the issue persists, there may be a problem with the machine's sensors or suspension system. In this case, it is recommended to contact LG customer support or a qualified technician for further assistance.
#
#
# question:  There is some odor coming from the washer can you tell me why?
# Answer: There are a few possible causes for the odor coming from the washer. One possible cause is that the rubber attached to the washing machine is causing the odor, which is normal for new rubber and will go away after running the machine a few times. Another possible cause is that the rubber door gasket and door seal area are not being cleaned regularly, leading to odors from mold or foreign substances. Additionally, odors can occur if foreign substances are left in the drainage pump filter or if the drainage hose is not properly installed, causing water to flow back into the machine. If you are using the dryer function, odors can also occur from lint and other laundry matter sticking to the heater. Regularly cleaning the gasket, door seal, drainage pump filter, and ensuring proper installation of the drainage hose can help eliminate these odors.
#
#
# question:  I can see IE error on my screen, how to resolve this?
# Answer: The IE error message typically appears when the water pressure is low or when the inlet filter is clogged with dirt. To resolve this issue, you can try the following steps:
#
# 1. Check if the water supply faucets are fully open. Make sure they are turned on completely.
#
# 2. Inspect the water inlet hoses to ensure they are not kinked, pinched, or crushed. If you find any issues, carefully straighten them out.
#
# 3. Clean the inlet filters. These filters can become clogged with dirt over time. Refer to the maintenance instructions for your specific washer model on how to clean the inlet filters.
#
# 4. If none of the above steps resolve the issue, it is possible that the water supply pressure to the faucet or house is too low. In this case, you may need to contact a professional plumber to check and adjust the water pressure.
#
# If the problem persists after trying these steps, it is recommended to consult the user manual or contact the manufacturer's customer support for further assistance.
#
#
# question:  Why is water being added to the washer after it has already started to run?
# Answer: The water may be added to the washer after it has already started running because the washer is adapting to the load size and type. It may need to add more water to ensure proper saturation of the clothing. This is a normal operation of the washer.
#
#
# question:  my washer displays FF error code
# Answer: The FF error code on your washer indicates a frozen error. This means that either the inlet hose, drain hose, or drain pump is frozen. The solution is to refer to the care instructions for cold climates.
#
#
# question:  what to do when the washing machine not work when door is open?
# Answer: If the washing machine is not working when the door is open, there could be a few possible causes. Here are some troubleshooting steps you can try:
#
# 1. Check if the door is fully closed: Make sure that the door is securely closed and nothing is caught under the door preventing it from closing completely. If the door is not closed properly, the machine may not start.
#
# 2. Check the water level: If the water level inside the machine is too high, the door may lock and cannot be opened. Wait for the water level to decrease or try canceling the cycle to release the door lock.
#
# 3. Check for error codes: Some washing machines display error codes when there is a problem. Refer to the user manual or the manufacturer's website to identify any error codes and follow the recommended troubleshooting steps.
#
# 4. Power cycle the machine: Turn off the washing machine and unplug it from the power source. Wait for a few minutes, then plug it back in and try starting the machine again.
#
# If none of these steps resolve the issue, it is recommended to contact the manufacturer's customer support or a professional technician for further assistance.
#
#
# question:  There is some odor coming from the washer, can you tell me why?
# Answer: There are a few possible causes for the odor coming from the washer. One possible cause is that the rubber attached to the washing machine can emit an odor, especially if it is new. This odor is normal and will go away after running the machine a few times. Another cause could be mold or foreign substances in the rubber door gasket and door seal area. Regular cleaning of these areas can help prevent odors. Odors can also occur if there are foreign substances in the drainage pump filter or if the drainage hose is not properly installed, causing water to flow back into the machine. Additionally, if you are using the dryer function, odors can occur from lint and other laundry matter sticking to the heater. Regular cleaning of the drainage pump filter and proper installation of the drainage hose can help prevent these odors.
#
#
# question:  what should I do further if sudsing continues?
# Answer: If sudsing continues, even after reducing the amount of detergent used, there are a few steps you can take:
#
# 1. Check the detergent: Make sure you are using a high-efficiency (HE) detergent that is specifically designed for HE washers. Look for the HE logo on the detergent packaging.
#
# 2. Adjust the detergent quantity: Refer to the detergent use instructions provided by the manufacturer. Use only 1/4 to 1/2 of the maximum amount recommended. If the load is small or lightly soiled, or if the water is very soft, further reduce the amount of detergent used.
#
# 3. Add an extra rinse: If sudsing or detergent residue continues to be an issue, try adding an extra rinse cycle to ensure thorough rinsing of the clothes.
#
# If these steps do not resolve the sudsing issue, it may be helpful to consult the washer's user manual or contact the manufacturer for further assistance.
#
#
# question:  I want to know the warranty period
# Answer: The warranty period for the washer is as follows:
#
# - Parts and labor (internal/functional parts only): one (1) year from the date of original retail purchase.
# - Parts only: three (3) years from the date of original retail purchase.
# - Parts only: ten (10) years from the date of original retail purchase.
#
# Please note that if the original date of purchase cannot be verified, the warranty will begin sixty (60) days from the date of manufacture. Additionally, you may be responsible for any applicable labor costs.
#
#
# question:  Is there any information on the product warranty?
# Answer: Yes, there is information on the product warranty. The warranty covers replacement products and parts, which may be new, reconditioned, refurbished, or factory remanufactured. The replaced product or parts will be the property of LG. To obtain warranty service, proof of original retail purchase specifying the product model and date of purchase is required. If there is no proof of purchase, the warranty start date will be ninety (90) days from the manufacture date. All costs and expenses associated with excluded circumstances listed under the warranty will be borne by the consumer. For more information and to obtain warranty service, you can call 1-888-542-2623 or visit the LG website at http://www.lg.com.
#
#
# question:  How long is the warranty period for the product?
# Answer: The warranty period for the product varies depending on the specific part or component. The warranty periods are as follows:
#
# - Parts and labor (internal/functional parts only): One (1) year from the date of original retail purchase.
# - Parts only: Ten (10) years from the date of original retail purchase.
# - Parts only: Three (3) years from the date of original retail purchase.
#
# Please note that if the original date of purchase cannot be verified, the warranty will begin sixty (60) days from the date of manufacture. Additionally, you are responsible for any applicable labor costs.
#
#
# question:  what steps are taken to resolve the dispute?
# Answer: To resolve the dispute, the first step is for the parties involved to attempt to resolve it within 30 days of LG's receipt of the notice of dispute. If they are unable to reach a resolution, the next step is to proceed to binding arbitration. The arbitration process will be conducted according to the procedure outlined in the agreement. During the arbitration proceeding, any settlement offers made by either party will not be disclosed to the arbitrator until a determination is made.
#
#
# question:  Is there a way to resolve disputes?
# Answer: Yes, according to the provided context, disputes between you and LG can be resolved through binding arbitration. This means that both parties are waiving the right to a jury trial and to bring or participate in a class action.
#
#
# question:  dispute resolution?
# Answer: Dispute resolution refers to the process of resolving a claim, action, dispute, or controversy between two parties. It involves finding a solution or reaching an agreement through negotiation, mediation, arbitration, or other means.
#
#
# question:  Product Warranty Guide
# Answer: The product warranty guide states that noises associated with normal operation and failure to follow instructions will not be covered under the warranty. It also mentions that all costs and expenses associated with excluded circumstances will be borne by the consumer. The warranty does not cover service trips for delivery, installation, or education on how to operate the product. It also does not cover damage or failure during power failures or inadequate electrical service. For warranty service and additional information, the user can call 1-888-542-2623 or visit the website at http://www.lg.com.
#
#
# question:  Please give warranty related information
# Answer: To obtain warranty service and additional information, you can call LG at 1-888-542-2623 and select the appropriate option from the menu. You can also visit their website at http://www.lg.com. If you prefer to contact them by mail, you can send a letter to LG Electronics, P.O. Box 240007, Huntsville, AL 35813, Attn: Customer Service.
#
# Please note that the warranty does not cover costs and expenses associated with excluded circumstances, as listed under the heading "This Limited Warranty Does Not Cover." The cost of repair or replacement under these excluded circumstances will be borne by the consumer. Additionally, noises associated with normal operation and failure to follow instructions or operating the unit in an unsuitable environment are not covered under the warranty.
#
#
# question:  what things are not covered under limited warranty for USA?
# Answer: Under the limited warranty for the USA, the following things are not covered:
#
# 1. Service trips to deliver, pick up, or install the product, or to educate on how to operate the product.
# 2. Correcting wiring or plumbing issues.
# 3. Correcting unauthorized repairs or installations of the product.
# 4. Damage or failure of the product to perform during power failures and interrupted or inadequate electrical service.
#
# Please note that this is not an exhaustive list, and there may be other items not covered under the limited warranty. It is always recommended to refer to the specific terms and conditions of the warranty for complete information.
#
#
# question:  Please let me know the quality period of the product
# Answer: The quality period of the product is not specified in the given context.

# %%
with open('data/TestCases/combined_data_answers.txt','w') as f:
    for ans in answers:
        f.write(ans+'\n')

# %%
import pandas as pd

# %%
df = pd.read_excel('data/TestCases/combined_data.xlsx')
df['LLM'] = answers
df.to_excel('data/TestCases/combined_data.xlsx',index=False)
